# %% [markdown]
# # Debugging cone noise STAs

# %%
import retinanalysis as ra
# Out:
# [2026-05-18 16:55:08,606][INFO]: DataJoint 0.14.4 connected to root@127.0.0.1:3306

# %%
ra.populate_database()
# Out:
# Need to convert /mnt/Volumes/data-1/data/h5/20230706C.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2023-07-13.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20231003C_old.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/test.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20240117C_old.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20240514C.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20220405C_mouse.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20240418C.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20240718C.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/sawtooth_20241216C_calibrations.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/sawtooth_20250122C_calibrations.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/led_sine_calibration_20250207C.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/led_sawtooth_calibrations_20250210C.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20250401C.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20250417C.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2025-04-29_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20250522C.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/crf_calibrations_20250609C.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20250611H.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/crf_calibrations_20250615C.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/crf_calibrations_20250623C.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/dragos_frametime_test.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/test_08062025H.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/frame_calibration_20250821C.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20220329C_mouse.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20240813E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20250304C.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20250515C.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20250709C.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20250729H.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20250815C.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20250908C.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20251013H.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/test_20251104H.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20251121_noise_regen.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/noise_test_0921.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20251124H.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20251219H.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2025-12-15_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2025-12-16_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-01-27_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-01-28_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20260211C.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20260211H.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20260219H.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20260220H.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-02-19_E_2.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-02-19_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-02-20_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-02-24_E_2.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-02-24_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-02-25_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-02-26_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-03-04_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-03-05_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-03-12_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-03-17_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-03-19_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-04-02_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-04-03_E_2.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-04-04_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-04-14_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-04-15_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-04-16_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-04-17_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-04-18_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20260415H.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20260428C.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/20260506H.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-04-23_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-04-24_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-04-28_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-04-29_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-05-06_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-05-07_E.h5 to json
# going to implement this eventually
# Need to convert /mnt/Volumes/data-1/data/h5/2026-05-08_E.h5 to json
# going to implement this eventually
# Experiments:   0%|          | 0/206 [00:00<?, ?it/s]
# Already in database: 20230614C
# Already in database: 20230713C
# Already in database: 20230719C
# Already in database: 20241010H
# Already in database: 20241016C
# Already in database: 20250128C
# Already in database: 20220405C
# Already in database: 20220406C
# Already in database: 20220412C
# Already in database: 20220420C
# Already in database: 20220426C
# Already in database: 20220518C
# Already in database: 20220526C
# Already in database: 20220531C
# Already in database: 20220607C
# Already in database: 20220705C
# Already in database: 20220712C
# Already in database: 20220726C
# Already in database: 20220809C
# Already in database: 20220816C
# Already in database: 20220818C
# Already in database: 20220823C
# Already in database: 20220829C
# Already in database: 20220909C
# Already in database: 20221006C
# Already in database: 20221024C
# Already in database: 20221101C
# Already in database: 20221114C
# Already in database: 20221117C
# Already in database: 20221123C
# Already in database: 20221216C
# Already in database: 20221219C
# Already in database: 20221228C
# Already in database: 20230105C
# Already in database: 20230109C
# Already in database: 20230111C
# Already in database: 20230202C
# Already in database: 20230207C
# Already in database: 20230214C
# Already in database: 20230221C
# Already in database: 20230228C
# Already in database: 20230313C
# Already in database: 20230314C
# Already in database: 20230320C
# Already in database: 20230322C
# Already in database: 20230324C
# Already in database: 20230328C
# Already in database: 20230329C
# Already in database: 20230406C
# Already in database: 20230411C
# Already in database: 20230418C
# Already in database: 20230502C
# Already in database: 20230511C
# Already in database: 20230516C
# Already in database: 20230517C
# Already in database: 20230523C
# Already in database: 20230524C
# Already in database: 20230525C
# Already in database: 20230530C
# Already in database: 20230607C
# Already in database: 20230613C
# Already in database: 20230621C
# Already in database: 20230622C
# Already in database: 20230629C
# Already in database: 20230725C
# Already in database: 20230802C
# Already in database: 20230808C
# Already in database: 20230825C
# Already in database: 20230829C
# Already in database: 20230926C
# Already in database: 20231003C
# Already in database: 20231011C
# Already in database: 20231026C
# Already in database: 20231108C
# Already in database: 20231129C
# Already in database: 20231220C
# Already in database: 20240117C
# Already in database: 20240130C
# Already in database: 20240201C
# Already in database: 20240213C
# Already in database: 20240215C
# Already in database: 20240229C
# Already in database: 20240319H
# Already in database: 20240326C
# Already in database: 20240328C
# Already in database: 20240328H
# Already in database: 20240401C
# Already in database: 20240401H
# Already in database: 20240409C
# Already in database: 20240418H
# Already in database: 20240424C
# Already in database: 20240424H
# Already in database: 20240523C
# Already in database: 20240606H
# Already in database: 20240611H
# Already in database: 20240618H
# Already in database: 20240620C
# Already in database: 20240627C
# Already in database: 20240627H
# Already in database: 20240717C
# Already in database: 20240717H
# Already in database: 20240718H
# Already in database: 20240801C
# Already in database: 20240806C
# Already in database: 20240806H
# Already in database: 20240813C
# Already in database: 20240813H
# Already in database: 20240820C
# Already in database: 20240926C
# Already in database: 20240926H
# Already in database: 20241121C
# Already in database: 20241121H
# Already in database: 20250121C
# Already in database: 20250131C
# Already in database: 20250212C
# Already in database: 20250219C
# Already in database: 20250219H
# Already in database: 20250304H
# Already in database: 20250306C
# Already in database: 20250306H
# Already in database: 20250307C
# Already in database: 20250321C
# Already in database: 20250429C
# Already in database: 20250429H
# Already in database: 20250514C
# Already in database: 20250527C
# Already in database: 20250529C
# Already in database: 20250530C
# Already in database: 20250626H
# Already in database: 20250710C
# Already in database: 20250710H
# Already in database: 20250715C
# Already in database: 20250715H
# Already in database: 20250729C
# Already in database: 20250730C
# Already in database: 20250730H
# Already in database: 20250814C
# Already in database: 20250814H
# Already in database: 20250829C
# Already in database: 20250829H
# Already in database: 20250911C
# Already in database: 20250917H
# Already in database: 20250917C
# Already in database: 20250924C
# Already in database: 20250924H
# Already in database: 20251006C
# Already in database: 20251006H
# Already in database: 20251008H
# Already in database: 20251008C
# Already in database: 20251015C
# Already in database: 20251015H
# Already in database: 20251022C
# Already in database: 20251022H
# Already in database: 20251106C
# Already in database: 20251106H
# Already in database: 20251110C
# Already in database: 20251112H
# Already in database: 20251112C
# Already in database: 20251113H
# Already in database: 20251119H
# Already in database: 20251119C
# Already in database: 20251124C
# Already in database: 20251125C
# Already in database: 20251202C
# Already in database: 20251202H
# Already in database: 20251215C
# Already in database: 20251216C
# Already in database: 20260102H
# Already in database: 20260102C
# Already in database: 20260107H
# Already in database: 20260107C
# Already in database: 20260113C
# Already in database: 20260120H
# Already in database: 20260120C
# Already in database: 20260127H
# Already in database: 20260127C
# Already in database: 20260204H
# Already in database: 20260204C
# Already in database: 2026-01-02_E_2
# Already in database: 20260218C
# Already in database: 20260219C
# Already in database: 20260224C
# Already in database: 20260226C
# Already in database: 20260226H
# Already in database: 20260303C
# Already in database: 20260303H
# Already in database: 2026-03-03_E
# Already in database: 2026-03-10_E
# Already in database: 2026-03-09_E
# Already in database: 20260318H
# Already in database: 20260317C
# Already in database: 20260318C
# Already in database: 2026-03-18_E
# Already in database: 20260401C
# Already in database: 20260401H
# Already in database: 20260403C
# Already in database: 2026-04-03_E
# Already in database: 20260410C
# Already in database: 20260410H
# Already in database: 20260414C
# Already in database: 20260415C
# Already in database: 20260417H
# Already in database: 20260423H
# Already in database: 20260424C
# Adding /mnt/Volumes/data-1/datajoint_testbed/mea/meta/20260506C.json
# Adding analysis for experiment 205, 20260506C
# Looking in /mnt/Volumes/data-1/data/sorted/20260506C
# Adding /mnt/Volumes/data-1/datajoint_testbed/mea/meta/20260508C.json
# Adding analysis for experiment 206, 20260508C
# Looking in /mnt/Volumes/data-1/data/sorted/20260508C
# Finding CellTypeFile entries for each chunk...
#   0%|          | 0/15 [00:00<?, ?it/s]
# Found 5 text files in analysis directories.
# There are now 550 entries in CellTypeFile.

# %%
exp_name = '20260508C'
chunk_name = 'cone_noise'
ra.get_exp_summary(exp_name)
# Out:
#      exp_name prep_label datafile_name           group_label  NDF  chunk_name  \
# 0   20260508C     Mount1       data000                 noise  1.0      chunk1
# 1   20260508C     Mount1       data001                 noise  1.0      chunk1
# 2   20260508C     Mount1       data002                   CRF  1.0      chunk1
# 3   20260508C     Mount1       data003            moving bar  1.0  moving_bar
# 4   20260508C     Mount1       data004  Defocus 150 With Gap  1.0     defocus
# 5   20260508C     Mount1       data005  Defocus 150 With Gap  1.0     defocus
# 6   20260508C     Mount1       data006  Defocus 150 With Gap  1.0     defocus
# 7   20260508C     Mount1       data007    Defocus 150 No Gap  1.0     defocus
# 8   20260508C     Mount1       data008    Defocus 150 No Gap  1.0     defocus
# 9   20260508C     Mount1       data009    Defocus 150 No Gap  1.0     defocus
# 10  20260508C     Mount1       data010                 noise  1.0      chunk2
# 11  20260508C     Mount1       data011                   CRF  1.0      chunk2
# 12  20260508C     Mount1       data012            Cone Noise  1.0  cone_noise
# 13  20260508C     Mount1       data013                 noise  1.0      chunk2
# 14  20260508C     Mount1       data014       Blue Moving Bar  1.0    blue_bar
#
#                                      protocol_name  duration_minutes  \
# 0               manookinlab.protocols.SpatialNoise             30.97
# 1               manookinlab.protocols.SpatialNoise             30.98
# 2    manookinlab.protocols.ContrastResponseGrating              5.50
# 3         manookinlab.protocols.MovingChromaticBar             15.32
# 4   edu.washington.riekelab.protocols.DefocusNoise             14.52
# 5   edu.washington.riekelab.protocols.DefocusNoise             14.48
# 6   edu.washington.riekelab.protocols.DefocusNoise             14.55
# 7   edu.washington.riekelab.protocols.DefocusNoise             11.18
# 8   edu.washington.riekelab.protocols.DefocusNoise             11.18
# 9   edu.washington.riekelab.protocols.DefocusNoise             11.18
# 10              manookinlab.protocols.SpatialNoise             30.97
# 11   manookinlab.protocols.ContrastResponseGrating              5.52
# 12              manookinlab.protocols.SpatialNoise            126.80
# 13              manookinlab.protocols.SpatialNoise             61.78
# 14        manookinlab.protocols.MovingChromaticBar              5.88
#
#     minutes_since_start          start_time            end_time  \
# 0                 30.97 2026-05-08 16:21:32 2026-05-08 16:52:30
# 1                 63.17 2026-05-08 16:53:43 2026-05-08 17:24:42
# 2                 69.10 2026-05-08 17:25:08 2026-05-08 17:30:38
# 3                 84.85 2026-05-08 17:31:04 2026-05-08 17:46:23
# 4                101.58 2026-05-08 17:48:36 2026-05-08 18:03:07
# 5                116.32 2026-05-08 18:03:22 2026-05-08 18:17:51
# 6                131.78 2026-05-08 18:18:46 2026-05-08 18:33:19
# 7                143.65 2026-05-08 18:34:00 2026-05-08 18:45:11
# 8                155.42 2026-05-08 18:45:46 2026-05-08 18:56:57
# 9                167.20 2026-05-08 18:57:33 2026-05-08 19:08:44
# 10               198.73 2026-05-08 19:09:18 2026-05-08 19:40:16
# 11               204.98 2026-05-08 19:41:00 2026-05-08 19:46:31
# 12               332.78 2026-05-08 19:47:31 2026-05-08 21:54:19
# 13               405.13 2026-05-08 22:04:53 2026-05-08 23:06:40
# 14               411.38 2026-05-08 23:07:02 2026-05-08 23:12:55
#
#              data_dir  experiment_id  prep_id  group_id  block_id  chunk_id  \
# 0   20260508C/data000            206      244      3107      5004       945
# 1   20260508C/data001            206      244      3108      5005       945
# 2   20260508C/data002            206      244      3109      5006       945
# 3   20260508C/data003            206      244      3110      5007       941
# 4   20260508C/data004            206      244      3111      5008       942
# 5   20260508C/data005            206      244      3111      5009       942
# 6   20260508C/data006            206      244      3111      5010       942
# 7   20260508C/data007            206      244      3112      5011       942
# 8   20260508C/data008            206      244      3112      5012       942
# 9   20260508C/data009            206      244      3112      5013       942
# 10  20260508C/data010            206      244      3113      5014       944
# 11  20260508C/data011            206      244      3114      5015       944
# 12  20260508C/data012            206      244      3115      5016       943
# 13  20260508C/data013            206      244      3116      5017       944
# 14  20260508C/data014            206      244      3117      5018       940
#
#     protocol_id
# 0            19
# 1            19
# 2             3
# 3             8
# 4            93
# 5            93
# 6            93
# 7            93
# 8            93
# 9            93
# 10           19
# 11            3
# 12           19
# 13           19
# 14            8

# %%
d_data = ra.sta.get_data_for_chunk(exp_name=exp_name, chunk_name=chunk_name)
